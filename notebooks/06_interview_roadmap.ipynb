# %% [markdown]
# # Interview_Roadmap
# ### Purpose:
# - Create interview preparation roadmap.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/leetcode_dataset - lc.csv")

df.head()
# Out:
#    id                                           title  \
# 0   1                                         Two Sum
# 1   2                                 Add Two Numbers
# 2   3  Longest Substring Without Repeating Characters
# 3   4                     Median of Two Sorted Arrays
# 4   5                   Longest Palindromic Substring
#
#                                          description  is_premium difficulty  \
# 0  Given an array of integers `nums` and an integ...           0       Easy
# 1  You are given two non-empty linked lists repre...           0     Medium
# 2  Given a string `s`, find the length of the lon...           0     Medium
# 3  Given two sorted arrays `nums1` and `nums2` of...           0       Hard
# 4  Given a string `s`, return the longest palindr...           0     Medium
#
#                                        solution_link  acceptance_rate  \
# 0                                  /articles/two-sum             46.7
# ...

# %%
easy = df[df["difficulty"]=="Easy"]

medium = df[df["difficulty"]=="Medium"]

hard = df[df["difficulty"]=="Hard"]

# %%
easy.shape
medium.shape
hard.shape
# Out:
# (385, 19)

# %%
print("Easy Problems:", len(easy))
print("Medium Problems:", len(medium))
print("Hard Problems:", len(hard))
# Out:
# Easy Problems: 477
# Medium Problems: 963
# Hard Problems: 385

# %% [markdown]
# ## Top Accepted Problems

# %%
df.sort_values(
    by="acceptance_rate",
    ascending=False
)[["title","difficulty","acceptance_rate"]].head(20)
# Out:
#                                                   title difficulty  \
# 1756                    Recyclable and Low Fat Products       Easy
# 1264             Print Immutable Linked List in Reverse     Medium
# 1782                                  Grand Slam Titles     Medium
# 1740             Find Total Time Spent by Each Employee       Easy
# 1569                  Dot Product of Two Sparse Vectors     Medium
# 1392                                  Capital Gain/Loss     Medium
# 1444                                   Apples & Oranges     Medium
# 1682                                     Invalid Tweets       Easy
# 1692                           Daily Leads and Partners       Easy
# 1794                           Rearrange Products Table       Easy
# 1118                        Remove Vowels from a String       Easy
# 1349                  Students With Invalid Departments       Easy
# 1377     Replace Employee ID With The Unique Identifier       Easy
# ...

# %% [markdown]
# ### Theory
# - Start with Easy problems.
# - Move to Medium problems.
# - Practice Hard challenges.
# - Focus on high-frequency questions.
# - Build interview roadmap.
