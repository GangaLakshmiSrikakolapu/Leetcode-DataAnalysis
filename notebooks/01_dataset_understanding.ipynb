# %% [markdown]
# # Dataset_understanding
# ### Purpose:
# - Understand dataset structure, columns, datatypes, missing values.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/raw/leetcode_dataset - lc.csv")

# %%
df.head()
# Out:
#    id                                           title  \
# 0   1                                         Two Sum
# 1   2                                 Add Two Numbers
# 2   3  Longest Substring Without Repeating Characters
# 3   4                     Median of Two Sorted Arrays
# 4   5                   Longest Palindromic Substring
#
#                                          description  is_premium difficulty  \
# 0  Given an array of integers `nums` and an integ...           0       Easy
# 1  You are given two non-empty linked lists repre...           0     Medium
# 2  Given a string `s`, find the length of the lon...           0     Medium
# 3  Given two sorted arrays `nums1` and `nums2` of...           0       Hard
# 4  Given a string `s`, return the longest palindr...           0     Medium
#
#                                        solution_link  acceptance_rate  \
# 0                                  /articles/two-sum             46.7
# ...

# %%
df.tail()
# Out:
#         id                                           title  \
# 1820  1821  Find Customers With Positive Revenue this Year
# 1821  1822                 Sign of the Product of an Array
# 1822  1823            Find the Winner of the Circular Game
# 1823  1824                           Minimum Sideway Jumps
# 1824  1825                              Finding MK Average
#
#                                             description  is_premium  \
# 1820                                         SQL Schema           1
# 1821  There is a function `signFunc(x)` that returns...           0
# 1822  There are `n` friends that are playing a game....           0
# 1823  There is a 3 lane road of length `n` that cons...           0
# 1824  You are given two integers, `m` and `k`, and a...           0
#
#      difficulty solution_link  acceptance_rate  frequency  \
# 1820       Easy           NaN             88.9        0.0
# 1821       Easy           NaN             67.8        0.0
# ...

# %%
df.shape
# Out:
# (1825, 19)

# %%
df.columns
# Out:
# Index(['id', 'title', 'description', 'is_premium', 'difficulty',
#        'solution_link', 'acceptance_rate', 'frequency', 'url', 'discuss_count',
#        'accepted', 'submissions', 'companies', 'related_topics', 'likes',
#        'dislikes', 'rating', 'asked_by_faang', 'similar_questions'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1825 non-null   int64
#  1   title              1825 non-null   str
#  2   description        1825 non-null   str
#  3   is_premium         1825 non-null   int64
#  4   difficulty         1825 non-null   str
#  5   solution_link      987 non-null    str
#  6   acceptance_rate    1825 non-null   float64
#  7   frequency          1825 non-null   float64
#  8   url                1825 non-null   str
#  9   discuss_count      1825 non-null   int64
#  10  accepted           1825 non-null   str
#  11  submissions        1825 non-null   str
#  12  companies          1749 non-null   str
#  13  related_topics     1571 non-null   str
#  14  likes              1825 non-null   int64
#  15  dislikes           1825 non-null   int64
#  16  rating             1825 non-null   int64
# ...

# %%
df.describe(include="all")
# Out:
#                  id    title description   is_premium difficulty  \
# count   1825.000000     1825        1825  1825.000000       1825
# unique          NaN     1825        1670          NaN          3
# top             NaN  Two Sum  SQL Schema          NaN     Medium
# freq            NaN        1         156          NaN        963
# mean     913.000000      NaN         NaN     0.218082        NaN
# std      526.976438      NaN         NaN     0.413057        NaN
# min        1.000000      NaN         NaN     0.000000        NaN
# 25%      457.000000      NaN         NaN     0.000000        NaN
# 50%      913.000000      NaN         NaN     0.000000        NaN
# 75%     1369.000000      NaN         NaN     0.000000        NaN
# max     1825.000000      NaN         NaN     1.000000        NaN
#
#             solution_link  acceptance_rate    frequency  \
# count                 987      1825.000000  1825.000000
# unique                987              NaN          NaN
# ...

# %%
df.isnull().sum()
# Out:
# id                      0
# title                   0
# description             0
# is_premium              0
# difficulty              0
# solution_link         838
# acceptance_rate         0
# frequency               0
# url                     0
# discuss_count           0
# accepted                0
# submissions             0
# companies              76
# related_topics        254
# likes                   0
# dislikes                0
# rating                  0
# asked_by_faang          0
# similar_questions    1080
# dtype: int64

# %% [markdown]
# ### Theory
# - Dataset contains LeetCode problem information.
# - Check total rows and columns.
# - Understand datatypes.
# - Find missing values.
# - Observe important features
